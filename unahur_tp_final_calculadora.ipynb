# %% [markdown]
# Crear las funciones:
#
# - suma(sum1,sum2)
# - resta(rest1,rest2)
# - multiplicacion(mul1,mul2)
# - division(div1,div2)
# - divisonEntera(divE1,divE2)
# - restoDivisionEntera(rDivE1,rDivE2)
# - potencia(base,expo)
#
# Estas funciones deben recibir por parámetro enteros con los que va a operar, y debe imprimir por pantalla un texto que indique que operacion se realizó y el valor resultante de la operación.
#
# Ingreso de datos:
# Crear una función inputUsuario(textoAMostrar) que reciba por parámetro un texto para acompañar el ingreso de un dato pedido por consola, que convierta el dato recibido en entero, y lo retorne.

# %%
def suma(sum1,sum2):
# Propósito: Imprimir por pantalla la suma de **sum1** y **sum2**
# Parámetros: sum1 - numero - El primer numero a sumar
#             sum2 - numero - El segundo numero a sumar
# precondiciones: ninguna
# tipo: tupla
    suma = sum1 + sum2
    print(f"Suma: {sum1} + {sum2} = {suma}")
    return suma, "Suma"

def resta(rest1,rest2):
# Propósito: Imprimir por pantalla la resta de **rest1** y **rest2**
# Parámetros: rest1 - numero - El primer numero a restar
#             rest2 - numero - El segundo numero a restar
# precondiciones: ninguna
# tipo: tupla
    resta = rest1 - rest2
    print(f"Resta: {rest1} - {rest2} = {resta}")
    return resta, "Resta"

def multiplicacion(mul1,mul2):
# Propósito: Imprimir por pantalla la multiplicación de **mul1** y **mul2**
# Parámetros: mul1 - numero - El primer numero a multiplicarr
#             mul2 - numero - El segundo numero a multiplicar
# precondiciones: ninguna
# tipo: tupla
    multiplicar = mul1 * mul2
    print(f"Multiplicación: {mul1} * {mul2} = {multiplicar}")
    return multiplicar, "multiplicacion"

def division(div1,div2):
# Propósito: Imprimir por pantalla la división de **div1** y **div2**
# Parámetros: div1 - numero - El dividendo
#             div2 - numero - El divisor
# precondiciones: ninguna
# tipo: tupla
    division = div1 / div2
    print(f"Division: {div1} / {div2} = {division}")
    return division, "Division"

def divisonEntera(divE1,divE2):
# Propósito: Imprimir por pantalla la división entera de **divE1** y **divE2**
# Parámetros: divE1 - numero - El dividendo
#             divE2 - numero - El divisor
# precondiciones: ninguna
# tipo: tupla
    division = divE1 // divE2
    print(f"Division entera: {divE1} / {divE2} = {division}")
    return division, "Division Entera"

def restoDivisionEntera(rDivE1,rDivE2):
# Propósito: Imprimir por pantalla el resto entera de **rDivE1** y **rDivE2**
# Parámetros: rDivE1 - numero - El dividendo
#             rDivE2 - numero - El divisor
# precondiciones: ninguna
# tipo: tupla
    division = rDivE1 % rDivE2
    print(f"Resto: {rDivE1} % {rDivE2} = {division}")
    return division, "Resto Division Entera"

def potencia(base,expo):
# Propósito: Imprimir por pantalla la potencia de la base **base** elevado al exponente **expo**
# Parámetros: base - numero - La base
#             expo - numero - El exponente
# precondiciones: ninguna
# tipo: tupla
    potencia = base ** expo
    print(f"Potencia: {base} ^ {expo} = {potencia}")
    return potencia, "Potencia"

def inputUsuario(textoAMostrar):
# Propósito: Ingresar el dato **textoAmostrar** y retornarlo
# Parámetros: textoAMostrar - String - El texto a mostrar
# precondiciones: ninguna
# tipo: numero 
    inputUsuario = int(input(textoAMostrar))
    return inputUsuario


val1,val2 = suma(7,5)
print(val1,val2)
# Out:
# Suma: 7 + 5 = 12
# 12 Suma

# %% [markdown]
# **Calculadora:**
#
# Crear la función **`calculadora()`**, que mediante la **indicación del usuario** realice alguna de las operaciones anteriormente creadas.
#
# La función calculadora deberá **tomar un dato por consola**, y en base a ese dato **acceder a la operación** o **imprimir por pantalla** que hubo un **error**.
#
# Una vez validado el dato, **pedirle al usuario** los **números a operar** y **pasarlos a la función correspondiente**.
#
# Cuando se **termina** de ejecutar la operación , debe de **mostrar un mensaje de cierre de programa y terminar.**
#
# Para que el usuario tenga una **mejor visualización** de las opciones crearemos la función **`menu()`** que **mostrará por pantalla** todas las **opciones a tomar** e indicando el número de opción a utilizar en la calculadora para acceder a la operación deseada.

# %%
def calculadora():
# Propósito: Realizar operaciones matemáticas
# precondiciones: ninguna
# tipo: ninguna 
    menu()
    opcion = inputUsuario("Ingrese una operación ")
    if opcion == 1:
        suma(inputUsuario("Ingrese el primer numero"),inputUsuario("Ingrese el segundo numero"))
    elif opcion == 2:
        resta(inputUsuario("Ingrese el primer numero"),inputUsuario("Ingrese el segundo numero"))
    elif opcion == 3:
        multiplicacion(inputUsuario("Ingrese el primer numero"),inputUsuario("Ingrese el segundo numero"))
    elif opcion == 4:
        division(inputUsuario("Ingrese el primer numero"),inputUsuario("Ingrese el segundo numero"))
    elif opcion == 5:
        divisonEntera(inputUsuario("Ingrese el primer numero"),inputUsuario("Ingrese el segundo numero"))
    elif opcion == 6:
        restoDivisionEntera(inputUsuario("Ingrese el primer numero"),inputUsuario("Ingrese el segundo numero"))
    elif opcion == 7:
        potencia(inputUsuario("Ingrese el primer numero"),inputUsuario("Ingrese el segundo numero"))
    else:
        print("Error")

def menu():
# Propósito: Mostrar un menú con las operaciones a realizar
# precondiciones: ninguna
# tipo: ninguna  
    print("Ingrese la operación a realizar:")
    print("1- Suma ")
    print("2- Resta ")
    print("3- Multiplicación ")
    print("4- División ")
    print("5- División entera ")
    print("6- Resto división entera ")
    print("7- Potencia")
    print("8- Primos hasta")
    print("9- Historial")
    print("0- Salir")

# %% [markdown]
# **Números primos:**
#
# Crear la función **`esPrimo(num)`**, que toma por **parámetro un número entero** y **retorna un booleano** indicando **si es o no** un **número primo**. Un **número primo** es un número natural mayor que 1 que tiene únicamente dos **divisores** distintos: **él mismo y el 1**. EJ:(2,3,5,7,etc)
#
# Crear la función **`numerosPrimosHasta(num)`** toma por **parámetro un número entero** y **retorna una lista** con los **números primos desde el 2 hasta el número indicado**.
#
# Integrar la función **`numerosPrimosHasta(num)`** a nuestra calculadora.

# %%
def esPrimo(num):
    # Propósito: Indica si el numero **num** es primo o no
    # Parámetros: num - Numero - El número a saber si es primo
    # precondiciones: El numero ingresado debe ser mayor o igual a 2
    # tipo: booleano
    for i in range(2,num-1):
        if num % i == 0:
            return False
    return True

def numerosPrimosHasta(num):
    # Propósito: Retorna una lista de numeros primos hasta el numero **num** indicado
    # Parámetros: num - Numero - El número hasta saber si es primo
    # precondiciones: El numero ingresado debe ser mayor o igual a 2
    # tipo: Lista
    lista_primos = []
    for i in range(2,num):
        if esPrimo(i):
            lista_primos.append(i)
    return lista_primos

# %% [markdown]
# **Calculadora Parte 2:**
#
# Haremos que nuestra función **`calculadora()`** funcione **hasta que se le indique**. Haremos que se **repita el proceso** de pedir opción, ingreso de datos y mostrado de resultado hasta que lo **indique el usuario**.
#
# Para ello **agregaremos una opción más a nuestro menú** que será que al **ingresar 0 se terminara el programa** y agregaremos una **estructura de control** a nuestra función **`calculadora()`** que **evalúe la condición** anteriormente mencionada para **continuar iterando o terminar la función**.

# %%
def calculadora():
# Propósito: Realizar operaciones matemáticas
# precondiciones: ninguna
# tipo: ninguna 
    menu() 
    opcion = inputUsuario("Ingrese una operación ")
    while opcion != 0:
        if opcion == 1:
            val1 = inputUsuario("Ingrese el primer numero")
            val2 = inputUsuario("Ingrese el segundo numero")
            sumar = suma(val1,val2)
            agregarHistorial("Suma {val1} + {val2}", sumar)
        elif opcion == 2:
            resta(inputUsuario("Ingrese el primer numero"),inputUsuario("Ingrese el segundo numero"))
        elif opcion == 3:
            multiplicacion(inputUsuario("Ingrese el primer numero"),inputUsuario("Ingrese el segundo numero"))
        elif opcion == 4:
            division(inputUsuario("Ingrese el primer numero"),inputUsuario("Ingrese el segundo numero"))
        elif opcion == 5:
            divisonEntera(inputUsuario("Ingrese el primer numero"),inputUsuario("Ingrese el segundo numero"))
        elif opcion == 6:
            restoDivisionEntera(inputUsuario("Ingrese el primer numero"),inputUsuario("Ingrese el segundo numero"))
        elif opcion == 7:
            potencia(inputUsuario("Ingrese el primer numero"),inputUsuario("Ingrese el segundo numero"))
        elif opcion == 8:
            numerosPrimosHasta(inputUsuario("Ingrese el primer numero"))
        elif opcion == 9:
            historial()
        else:
            print("Error")
        opcion = inputUsuario("Ingrese una operación ")
    print("Gracias por usar la calculadora de Python")

calculadora()

# %% [markdown]
# **Historial:**
#
# Crear un **diccionario vacío** con el que iremos llevando un **historial de las operaciones realizadas** con nuestra calculadora.
#
# En el diccionario guardaremos como **KEY un texto que indica qué operación se realizó y con qué valores**, y en el **VALUE guardaremos el resultado de la operación**.
#
# Para **agregar estos datos al diccionario** creado, crearemos una función **`agregarHistorial(key, value)`** que recibe por **parámetro los datos para agregar un elemento más al diccionario**.
#
# Para **visualizar este historial**, crearemos la función **`historial()`** que **muestre por pantalla** el **historial de operaciones y resultados** hechos en esa ejecución.
#
# Integrar la función **`historial()`** a nuestra calculadora.

# %%
operaciones_realizadas = {}

def historial():
# Propósito: Mostrar el historial de operaciones
# tipo: ninguna
    for k,v in operaciones_realizadas.items():
        print(f"Operación realizada {k} y su resultado {v}")

def agregarHistorial(key, value):
# Propósito: Agrega al historial las operaciones realizadas juntos con sus valores
# precondiciones: key - String - La operación y valores realizados
#                 value - String - El resultado de la operación
# tipo: ninguna 
    operaciones_realizadas[key] = value

# %%
def calculadora():
# Propósito: Realizar operaciones matemáticas
# precondiciones: ninguna
# tipo: ninguna 
    menu() 
    opcion = inputUsuario("Ingrese una operación ")
    while opcion != 0:
        if opcion == 1:
            val1 = inputUsuario("Ingrese el primer numero")
            val2 = inputUsuario("Ingrese el segundo numero")
            suma(val1,val2)
            agregarHistorial(f"Suma {val1} + {val2}", val1 + val2)
        elif opcion == 2:
            val1 = inputUsuario("Ingrese el primer numero")
            val2 = inputUsuario("Ingrese el segundo numero")
            resta(val1,val2)
            agregarHistorial(f"Resta {val1} - {val2}", val1 - val2)
        elif opcion == 3:
            val1 = inputUsuario("Ingrese el primer numero")
            val2 = inputUsuario("Ingrese el segundo numero")
            multiplicacion(val1,val2)
            agregarHistorial(f"Multiplicación {val1} * {val2}", val1 * val2)
        elif opcion == 4:
            val1 = inputUsuario("Ingrese dividendo")
            val2 = inputUsuario("Ingrese divisor")
            division(val1,val2)
            agregarHistorial(f"División {val1} / {val2}", val1 / val2)
        elif opcion == 5:
            val1 = inputUsuario("Ingrese dividendo")
            val2 = inputUsuario("Ingrese divisor")
            divisonEntera(val1,val2)
            agregarHistorial(f"División Entera {val1} / {val2}", val1 // val2)
        elif opcion == 6:
            val1 = inputUsuario("Ingrese dividendo")
            val2 = inputUsuario("Ingrese divisor")
            restoDivisionEntera(val1,val2)
            agregarHistorial(f"Resto División Entera {val1} % {val2}", val1 % val2)
        elif opcion == 7:
            val1 = inputUsuario("Ingrese la base")
            val2 = inputUsuario("Ingrese el exponente")
            potencia(val1,val2)
            agregarHistorial(f"Potencia de {val1} elevado a {val2}", val1 ** val2)
        elif opcion == 8:
            val1 = inputUsuario("Ingrese el primer numero")
            np = numerosPrimosHasta(val1)
            print(np)
            agregarHistorial(f"Numeros primos hasta {val1}", np)
        elif opcion == 9:
            historial()
        else:
            print("Error")
        menu()
        opcion = inputUsuario("Ingrese una operación ")
    print("Gracias por usar la calculadora de Python")

calculadora()

# %%
# Refactorización de código

'''
En este apartado iré refactorizando las funciones anteriormente realizadas.
Primero, minificaré el código repetido
'''

'''
Este es un claro ejemplo de código repetido a simplificar 

if opcion == 1:
    val1 = inputUsuario("Ingrese el primer numero")
    val2 = inputUsuario("Ingrese el segundo numero")
    suma(val1,val2)
    agregarHistorial(f"Suma {val1} + {val2}", val1 + val2)
elif opcion == 2:
    val1 = inputUsuario("Ingrese el primer numero")
    val2 = inputUsuario("Ingrese el segundo numero")
    resta(val1,val2)
    agregarHistorial(f"Resta {val1} - {val2}", val1 - val2)
'''

'''
Primero, vemos qué datos son repetidos.
Los mismo, dejaremos como espacios o huecos
'''

'''
if opcion == 1:
    val1 = inputUsuario("Ingrese el primer numero")
    val2 = inputUsuario("Ingrese el segundo numero")
    suma(val1,val2)
    agregarHistorial(f"Suma {val1} + {val2}", val1 + val2)
elif opcion == 2:
    val1 = inputUsuario("Ingrese el primer numero")
    val2 = inputUsuario("Ingrese el segundo numero")
    resta(val1,val2)
    agregarHistorial(f"Resta {val1} - {val2}", val1 - val2)


if opcion == 1:
    (VALOR) = inputUsuario("Ingrese el primer numero")
    (VALOR) = inputUsuario("Ingrese el segundo numero") // REPETICION DE LINEA
    (FUNCIÓN)((VALOR),(VALOR))
    (FUNCION)(f"(VALOR) {(VALOR)} (+) {(VALOR)}", (VALOR) (+) (VALOR))
elif opcion == 2:
    (VALOR) = inputUsuario("Ingrese el primer numero")
    (VALOR) = inputUsuario("Ingrese el segundo numero") // REPETICION DE LINEA
    (FUNCION)((VALOR),(VALOR))
    (FUNCION)(f"(VALOR) {(VALOR)} (-) {(VALOR)}", (VALOR) (-) (VALOR))
'''

'''
Crearé una función que intercepte los dos valores y ejecute la función que las recibe
'''

def aplicar_funcion(funcion):
    # Propósito: Aplicar una función matemática con sus dos valores y guardarlo en el historial
    # Parámetros: funcion - función - La función a ejecutarse
    # precondiciones: ninguna
    # tipo: Nada 
    val1 = inputUsuario("Ingrese el primer numero")
    val2 = inputUsuario("Ingrese el segundo numero")
    # Desestructuro para guardar los dos retornos en variables
    resultado,operacion = funcion(val1,val2)
    agregarHistorial(f"{operacion} {val1} y {val2}", resultado)
'''
Ahora, para evitar el uso de if elif, vamos a crear un diccionario con todas las operaciones
'''

operaciones = {
    1: suma,
    2: resta,
    3: multiplicacion,
    4: division,
    5: divisonEntera,
    6: restoDivisionEntera,
    7: potencia,
    8: numerosPrimosHasta
}

'''
Voy a tener que modificar la naturaleza de las operaciones para que puedan retornar valores 
'''
def suma(sum1,sum2):
# Propósito: Imprimir por pantalla la suma de **sum1** y **sum2** y retornar su resultado
# Parámetros: sum1 - numero - El primer numero a sumar
#             sum2 - numero - El segundo numero a sumar
# precondiciones: ninguna
# tipo: tupla
    suma = sum1 + sum2
    print(f"Suma: {sum1} + {sum2} = {suma}")
    # Retorna el resultado y la operación
    return suma, "Suma"

# %%
'''
Modifico la función calculadora para poder usar las operaicones del diccionario
'''
opcion = inputUsuario("Ingrese una operación ")
if opcion >= 1 and opcion <= 7:
    aplicar_funcion(operaciones[opcion])

# %%
# Aplicando los cambios

operaciones = {
    1: suma,
    2: resta,
    3: multiplicacion,
    4: division,
    5: divisonEntera,
    6: restoDivisionEntera,
    7: potencia,
    8: numerosPrimosHasta
}

def aplicar_funcion(funcion):
    # Propósito: Aplicar una función matemática con sus dos valores y guardarlo en el historial
    # Parámetros: funcion - función - La función a ejecutarse
    # precondiciones: ninguna
    # tipo: Nada 
    val1 = inputUsuario("Ingrese el primer numero")
    val2 = inputUsuario("Ingrese el segundo numero")
    # Desestructuro para guardar los dos retornos en variables
    resultado, operacion = funcion(val1,val2)
    agregarHistorial(f"{operacion} {val1} y {val2}", resultado)

def calculadora():
# Propósito: Realizar operaciones matemáticas
# precondiciones: ninguna
# tipo: ninguna 
    menu() 
    opcion = inputUsuario("Ingrese una operación ")
    while opcion != 0:
        if opcion >= 1 and opcion <= 7:
            aplicar_funcion(operaciones.get(opcion))
        elif opcion == 8:
            val1 = inputUsuario("Ingrese el primer numero")
            np = numerosPrimosHasta(val1)
            print(np)
            agregarHistorial(f"Numeros primos hasta {val1}", np)
        elif opcion == 9:
            historial()
        else:
            print("Error")
        menu()
        opcion = inputUsuario("Ingrese una operación ")
    print("Gracias por usar la calculadora de Python")

calculadora()
